# %% [markdown]
# A continuacion descargamos usamos el IDE de Google para analizar el DATASET del creciemiento historico de S&P500, donde analizamos sus variables.
# **Abrir este archivo con el editor del github "github.dev"

# %%
pip install sweetviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 19.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import sweetviz as sv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ced2a23-6741-4f9b-83cd-2dbe379f4292" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ced2a23-6741-4f9b-83cd-2dbe379f4292">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['sp_500.csv']))

# %%
#analizando el Dataset
df2_report = sv.analyze(df2)
# display report
df2_report.show_html('plataforms_final.csv')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report plataforms_final.csv was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df2_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# CONCLUSIONES DEL EDA PARA EL S&P 500 HISTORICO
#
#
# 1.  En el anterior Reporte por medio de la libreria sweetviz observamos que tenemos 7 variables 6 numericas, una de texto y ninguna categorica. Tamboen observamos que hay 0 duplicados.
#
# 2.  Observamos las distribuciones de la apertura, el cierre, el cierre ajustado, el alto y el bajo con distribucione muy similares, donde su mayor concetracion se encuentra cuando el indice esta entre el 1000 y el 2000,replegado hacia la izquierda
#
# 3.  La variable volumen la vemos con una distribucion normal con su mayor concentracion hacia el centro.
# 4.  En el analisis descriptivo vemos su maximos que rondan los 4000 y los minimos que rodan los 600
# 5. Observamos en la correlacion de Pearson valores mayores a 1 y -1, viendo correlaciones positivas y negativas entre cierre y cierre ajustado del indice, como tambien con las variables alta y baja.
