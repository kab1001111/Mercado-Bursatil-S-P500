# %% [markdown]
# A continuacion descargamos y usamos el IDE de Google (COLAB) para analizar el DATASET del de las empresas y sectores del s&p500, donde analizamos sus variables.
# **Abrir este archivo con el editor del github "github.dev"

# %%
pip install sweetviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 19.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import numpy as np
import sweetviz as sv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-012b4249-6d6c-4f29-8d68-c1f8843765eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-012b4249-6d6c-4f29-8d68-c1f8843765eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['constituents-financials.csv']))

# %%
#analizando el Dataset
df2_report = sv.analyze(df2)
# display report
df2_report.show_html('constituents-financials.csv')
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report constituents-financials.csv was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df2_report.show_notebook()
# Out:
#  <iframe width="100%" height="750" srcdoc="&lt;!doctype html&gt;
# &lt;html lang=&quot;en&quot;&gt;
# &lt;head&gt;
#     &lt;meta charset=&quot;UTF-8&quot;&gt;
#     &lt;link rel=&quot;icon&quot; href=&quot;data:image/x-icon;base64,...&quot; type=&quot;image/x-icon&quot; /&gt;
#         &lt;script&gt; /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# CONCLUSIONES DEL EDA PARA EL DATAFRAME DEL 2 DATAFRAME DEL LAS EMPRESAS Y LOS SECTORES DEL S&P500
#
#
# 1.  En el anterior Reporte por medio de la libreria sweetviz observamos que tenemos 14 variables diez numericas, UNA de texto y una categorica. Tambien observamos que hay 0 duplicados. Son 15 columnas y 505 filas.
# 2.  La variable sector nos muestra los 11 sectores que componen el S&P500 con sus respetivos nombres agrupados por tamaño respecto al numero de emrpresas que lo componen.
#
# 2. Observamos las distribuciones de las variables en general mas inclinados hacia la izquierda.
# 3. Observamos correlaciones positivas entre el precio de la acción y las variables de tiempo de cotización.
# 5. Observamos en la correlación de Pearson negativa entre la variable EBITDA y Mercado de Capitales.
